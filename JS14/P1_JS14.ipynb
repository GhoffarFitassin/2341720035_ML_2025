# %% [markdown]
# # Praktikum 1

# %% [markdown]
# ## Langkah 1 - Import Library

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Langkah 2 - Pra Pengolahan Data

# %% [markdown]
# ### Langkah 2.1. Pra Pengolahan Data Training

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Datasets/dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 5122 images belonging to 2 classes.

# %% [markdown]
# ### Langkah 2.2. Pra Pengolahan Data Testing

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Datasets/dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# ## Langkah 3 - Pembuatan Model CNN

# %% [markdown]
# ### Langkah 3.1.  - Inisiasi Model CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Langkah 3.2. - Pembuatan Layer Konvolusi 1

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# ### Langkah 3.3 - Pembuatan Layer Pooling 1

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Langkah 3.4 - Pembuatan Layer Konvolusi 2 dan Pooling 2

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Langkah 3.5 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Langkah 3.6 - Fully Connected Layer 1 (Input)

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Langkah 3.7 - Fully Connected Layer 2 (Output)

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ### Langkah 3.8 - Compile Model CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ## Langkah 4 - Fit CNN

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 500s 3s/step - accuracy: 0.7526 - loss: 0.5633 - val_accuracy: 1.0000 - val_loss: 0.3002
# Epoch 2/25
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 63s 390ms/step - accuracy: 0.7902 - loss: 0.4926 - val_accuracy: 0.9820 - val_loss: 0.2082
# Epoch 3/25
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 64s 394ms/step - accuracy: 0.7929 - loss: 0.4753 - val_accuracy: 0.9480 - val_loss: 0.2654
# Epoch 4/25
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 79s 379ms/step - accuracy: 0.8119 - loss: 0.4473 - val_accuracy: 0.9920 - val_loss: 0.1594
# Epoch 5/25
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 66s 408ms/step - accuracy: 0.8117 - loss: 0.4381 - val_accuracy: 0.8470 - val_loss: 0.3762
# Epoch 6/25
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 62s 384ms/step - accuracy: 0.8196 - loss: 0.4177 - val_accuracy: 0.9520 - val_loss: 0.2284
# Epoch 7/25
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 66s 411ms/step - accuracy: 0.8194 - loss: 0.4120 - val_accuracy: 0.9510 - val_loss: 0.2050
# Epoch 8/25
# ...

# %% [markdown]
# ## Langkah 5 - Prediksi dengan 1 Citra

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/drive/MyDrive/Datasets/dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'

print(f"Prediction Data: {prediction}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Prediction Data: dog
